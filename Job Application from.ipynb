# %%
import tkinter as tk
from tkinter import *
 
root = tk.Tk()
root.geometry("412x800")
#root.title('Job Application from')

#Tkinter variable for storing entries
firstname = StringVar()
lastname = StringVar()
emailvalue = StringVar()
mobilenumbervalue = StringVar()
Resumevalues = StringVar()
address1_values = StringVar()
address2_values = StringVar()
hobbiesvalues = StringVar()
company_name = StringVar()
job_title = StringVar()
job_time = StringVar()
ref_name1 = StringVar()
ref_name2 = StringVar()
ref_phone1 = StringVar()
ref_phone2 = StringVar()




def getvals():
    print("Submitting form")

    print(f"{firstname.get(),lastname.get(),emailvalue.get(),menu.get(),mobilenumbervalue.get(),Resumevalues.get(),address1_values.get(),address2_values.get(), hobbiesvalues.get(), company_name.get(),job_title.get(),job_time.get(), ref_name1.get(), ref_name2.get(), ref_phone1.get(), ref_phone2.get()} ")



    with open("record.txt", "a") as f:
        f.write(f"{firstname.get(), lastname.get(),emailvalue.get(),menu.get(),mobilenumbervalue.get(),Resumevalues.get(),address1_values.get(),address2_values.get(),hobbiesvalues.get(),company_name.get(),job_title.get(), job_time.get(), ref_name1.get(), ref_name2.get(), ref_phone1.get(), ref_phone2.get()}\n ")




#Heading
#lable = tk.Label(root, text='Job Application from',font="comicsansms 13 bold",pady=15).grid(row=0, column=5)

label = tk.Label(root,text="Job application",font=(20)).place(x=140,y=10)

label = tk.Label(root,text="Personal information",fg='red').place(x=10,y=50)

label = tk.Label(root,text="Name").place(x=10,y=80)
name = tk.Entry(root,text="firstname", textvariable=firstname).place(x=70,y=80)
name = tk.Entry(root,text="lastname", textvariable=lastname).place(x=220,y=80)

label2 = tk.Label(root,text="Email").place(x=10,y=110)
email = tk.Entry(root,text="email", textvariable=emailvalue).place(x=70,y=110)

label2 = tk.Label(root,text="Education").place(x=10,y=140)
menu = tk.StringVar()
menu.set("please choose")
edu = tk.OptionMenu(root,menu,"Btech","Mtech","BSC").place(x=100,y=140)

label3 = tk.Label(root,text="Resume").place(x=10,y=190)

f =tk.Button(root,text="choose file").place(x=100,y=190)
f1 = tk.Entry(root,textvariable=Resumevalues).place(x=170,y=190)

label3 = tk.Label(root,text="Address").place(x=10,y=250)
e1 = tk.Entry(root,width=40,textvariable=address1_values).place(x=100,y=250)
e1 = tk.Entry(root,width=40,textvariable=address2_values).place(x=100,y=280)

menu = tk.StringVar()
menu.set("select country")

e1 = tk.OptionMenu(root,menu,"India","USA","Canada").place(x=100,y=310)

label3 = tk.Label(root,text="phone number", textvariable=mobilenumbervalue).place(x=10,y=360)
e2 = tk.Entry(root).place(x=100,y=360)

label3 = tk.Label(root,text="what are your hobbies?").place(x=10,y=390)
e2 = tk.Entry(root,width=50,textvariable=hobbiesvalues).place(x=10,y=410)

label = tk.Label(root,text="Previous/Current employment information",fg='red').place(x=10,y=450)
label3 = tk.Label(root,text="company name").place(x=10,y=470)
e2 = tk.Entry(root,textvariable='company_name').place(x=180,y=470)

label3 = tk.Label(root,text="job title").place(x=10,y=500)
e2 = tk.Entry(root,textvariable='job_title').place(x=180,y=500)

label3 = tk.Label(root,text="how long were you here?").place(x=10,y=530)
e2 = tk.Entry(root,textvariable='job_time').place(x=180,y=530)


label = tk.Label(root,text="Reference#1",font=(10),fg='red').place(x=10,y=560)
label3 = tk.Label(root,text="Name").place(x=10,y=600)
e2 = tk.Entry(root ,textvariable='ref_name1').place(x=180,y=600)
label3 = tk.Label(root,text="Phone").place(x=10,y=630)
e2 = tk.Entry(root ,textvariable='ref_phone1').place(x=180,y=630)


label = tk.Label(root,text="Reference#2",font=(10),fg='red').place(x=10,y=660)
label3 = tk.Label(root,text="Name").place(x=10,y=700)
e2 = tk.Entry(root,textvariable='ref_name2').place(x=180,y=700)

label3 = tk.Label(root,text="Phone").place(x=10,y=730)
e2 = tk.Entry(root,textvariable='ref_phone2').place(x=180,y=730)
btn =tk.Button(root,text="submit",bg="#B22727",command=getvals,fg='white').place(x=150,y=760)


root.mainloop()
